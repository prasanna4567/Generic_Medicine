# %%
import json 
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import time 
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import StaleElementReferenceException
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support import expected_conditions
from selenium.common import exceptions  
import re

# %%
browser = None
try:
    browser = webdriver.Chrome(executable_path='C:\\Users\\PRASANNA\\chromedriver_win32\\chromedriver.exe')
except Exception as error:
    print(error)

# %%
#link_treasure_box should be getting links from excel file 

link_treasure_box = ['https://www.medplusmart.com/compositionProducts/Piroxicam-20-MG/3940'] #Just to check
product_links_by_composition={}

for link in  link_treasure_box :
    name=link.split('/')[-2]
    try:
                browser.get(link)
            
                

    except Exception as err:
                print(str(err))
                break
    else:
                print('\nSuccessfully Accessed:',link)


    medicine_name_per_composition = browser.find_elements_by_xpath('//*[@id="productSearch"]/tbody/tr/td[1]/div/span/a')
    medicine_mfg_per_composition = browser.find_elements_by_xpath('//*[@id="productSearch"]/tbody/tr/td[2]')
    product_links={}
    for i,j in zip(medicine_name_per_composition,medicine_mfg_per_composition):
        x=i.get_attribute("text")
        y=j.get_attribute('textContent')
        product_links[x]=y
    product_links_by_composition[name]=product_links 
        
print(len(product_links_by_composition[name].keys()))
print(product_links_by_composition)
# Out:
# Successfully Accessed: https://www.medplusmart.com/compositionProducts/Piroxicam-20-MG/3940
# 202
# {'Piroxicam-20-MG': {'BREXIC DT 20MG TAB': 'WOCKHARDT', 'CAMLEY DT 20MG TAB': 'ZODLEY PHARMA', 'CAMPY 20MG TAB': 'POSITIF LIFESCIENCES', 'CAMPIR  DT 20MG TAB': 'MIYOTA HEALTH CARE', 'CAMROX 20MG TAB': 'ACTIVE HEALTHCARE', 'CAMSUN DT 20MG TAB': 'MADHAV BIOTECH', 'CAM EL DT 20MG TAB': 'MADHAV BIOTECH', 'ARTHRODAC 20MG TAB': 'BONSAI PHARMA', 'AMIPIRO 20MG TAB': 'AMIGOZ LIFE SCIENCES', 'ANROX 20MG TAB': 'AINGO PHARMA', 'APIROXY 20MG TAB': 'ASTERISK LABS PVT LTD', 'ARICAM 20MG TAB': 'SARIAN HEALTHCARE', 'BETAROX DT TAB': 'CAPRI PHARMA', 'BIOCAM 20MG TAB': 'BIOCHEMIX HEALTHCARE PVT LTD', 'BIODOL DT TAB': 'CHEMO BIOLOGICAL', 'BIONEX  20MG TAB': 'NEXBIO LIFE SCIENCES', 'DEOLREST DT TAB': 'KNOLL HEALTHCARE PVT LTD', 'DOLACAM DT 20MG TAB': 'INJECTO CAPTA', 'DOLCAM DT TAB': 'CIPLA', 'DOLCARE 20MG TAB': 'OLCARE LABORATORIES PVT LTD', 'DOLLODAC DT TAB': 'PHARMATECH HEALTHCARE', 'DOLONEX 20MG CAP': 'PFIZER LIMITED', 'DOLONEX DT 20MG TAB': 'PFIZER LIMITED', 'DOLONEX RAPID 20MG TAB': 'PFIZER LIMITED', 'DOLOGEN DT TAB': 'SYSTEMIC HEALTHCARE', 'DOLOKEM DT TAB': 'CHEMO HEALTHCARE PVT LTD', 'DOLOCHEM DT TAB': 'JANUS REMEDIES', 'DOLOCIP DT TAB': 'CIPLA', 'DOLOSWIFT 20MG CAP': 'IND SWIFT LIMITED', 'DOLOKAM DT 20MG TAB': 'CADILA PHARMACEUTICALS LTD', 'DOLONX CD TAB': 'ADCOCK INGRAM HEALTHCARE PVT LTD', 'DOLOAGE 20MG TAB': 'ALLENGE INDIA', 'DOLOXICAM 20MG TAB': 'TROIKAA PHARMACEUTICALS LTD', 'DOLOXIL DT 20MG TAB': 'MISSION LAB', 'DOLOVENT DT 20MG TAB': 'UNIVENTIS MEDICARE LTD', 'DOLOCAM DT 20MG TAB': 'WORLD WIDE REMEDIES', 'DOLOPIC DT 20MG TAB': 'PHARMA CORP INC PVT LTD', 'DOLONIP 20MG TAB': 'DHAMUS PHARMA', 'DOLODAC DT 20MG TAB': 'PHARMATECH HEALTHCARE', 'DOLODIFF DT 20MG TAB': 'PHARMATECH HEALTHCARE', 'DOLODIL 20MG DT TAB': 'MADHAV BIOTECH', 'DOLOSURE DT TAB': 'GROWMAX MEDICARE PVT LTD', 'DOLOCARE 20MG TAB': 'MADHAV BIOTECH', 'DOLOX DT 20MG TAB': 'ARONEX LIFE SCIENCE', 'DOLOCARE DT 20MG TAB': 'INDUS PHARMA PVT LTD', 'DOLROX 20MG TAB': 'BIOSYS MEDISCIENCES', 'DUPOX-DT 20MG TAB': 'DEPONE', 'ELPIROM DT TAB': 'ELDER PHARMACEUTICALS LTD', 'FLEXAR DT TAB': 'MEDICAMEN BIOTECH', 'FLEXTAB SR TAB': 'PSYCHOTROPICS INDIA LTD', 'FLOCALM 20MG TAB': 'ELORA AND PHARMA', 'FELCAM 20MG TAB': 'SUN PHARMACEUTICAL INDUSTRIES LTD', 'FELDEX 20MG TAB': 'SUN PHARMACEUTICAL INDUSTRIES LTD', 'FELOXIGEN 20MG CAP': 'GENPHARMA INTERNATIONAL PVT LTD', 'INCAM DT TAB': 'CAPITAL PHARMA', 'INFLAVAN 20MG TAB': 'KHANDELWAL LABORATORIES PVT LTD', 'INFLACIN 20MG TAB': 'IKON REMEDIES PVT LTD', 'JEPRAX 20MG TAB': 'STAR BIOMED PVT LTD', 'KALPROX DT 20MG TAB': 'HEAL ALL PHRAMACEUTICALS PVT LTD', 'KAMZ 20MG TAB': 'MADHAV BIOTECH', 'PROCAM 20MG DT TAB': 'PROTON REMEDIES', 'PROXYCAM 20MG TAB': 'HAB PHARMA', 'PROXICON 20GM CAP': 'AKMED BIOTECH', 'PRX DT 20MG TAB': 'SUNRISE REMEDIES PVT LTD', 'PYRAG DT 20MG TAB': 'AGRON REMEDIES', 'PYRAS DT 20MG TAB': 'MADHAV BIOTECH', 'PYRIMAX 20MG TAB': 'ODDIANT FORMULATIONS', 'PYRODEX TAB': 'SUN PHARMACEUTICAL INDUSTRIES LTD', 'PYROXEE 20MG TAB': 'DORPHYLL HEALTHCARE', 'Q GESIC 20MG TAB': 'NIMBLE PHARMA', 'SOLCAM 20MG TAB': 'BOFFIN BIOTECH PVT LTD', 'SPYRO TAB': 'GUFIC BIOSCIENCES LTD', 'STALUS MD 20MG TAB': 'XIEON LIFE SCIENCES PVT LTD', 'STARPIR MD 20MG TAB': 'SANTIAGO LIFE SCIENCES PVT LTD', 'STARCAM MD TAB': 'INVISION MEDI SCIENCE PVT LTD', 'STEROX 20MG TAB': 'STEPMED LIFESCIENCES', 'OSTEOCAM  MD TAB': 'UNICORN PHARMACEUTICALS', 'OXICAM 20MG DT TAB': 'ALEMBIC PHARMACEUTICALS LTD', 'PAINGESIC 20MG TAB': 'MEYER ORGANICS PVT LTD', 'PAINCOM DT 20MG TAB': 'ZYDUS HEALTHCARE LTD', 'PAINFREE DT TAB': 'SUNLIFE SCIENCES', 'PALAXI 20MG CAP': 'NANU INTERNATIONAL', 'PAM 20MG DT TAB': 'EAST WEST PHARMA', 'PAM 20MG TAB': 'EAST WEST PHARMA', 'LV PX 20MG TAB': 'LIZA LIFESCIENCES', 'ORTHOSTAR 20DT TAB': 'DYNAMED PHARMA', 'ORTHONEX DT 20MG TAB': 'POWER LABS', 'LONEX DT TAB': 'NOEL PHARMA INDIA PVT LTD', 'NEX DT 20MG TAB': 'ANTIGEN HEALTHCARE', 'KELAM 20MG TAB': 'KLOKTER LIFE SCIENCE', 'KEMONEX-DT TAB': 'CL REDDY PHARMACEUTICALS', 'LEAFCAM 20MG TAB': 'LIFE VISION HEALTHCARE', ...

# %%
''' To do
-> Populate the excel sheet
-> Dump all scraped medicine data as json/excel  
-> DB
-> Flask
'''
# Out:
# ' To do\n-> Populate the excel sheet\n-> Dump all scraped medicine data as json/excel  \n-> DB\n-> Flask\n'
